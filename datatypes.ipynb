# %%
# int,long, float, strings, coplex, boolean

# %%
a=10
b=20

# %%
print a+b
print a-b
print a*b
print a/b
print a**2
print a%3
# Out:
# 30
# -10
# 200
# 0
# 100
# 1

# %%
print 10/20
# Out:
# 0

# %%
print 10/20.0
# Out:
# 0.5

# %%
a=20
b=20.0

# %%
print type(a)
# Out:
# <type 'int'>

# %%
type(b)
# Out:
# float

# %%
a=2**200

# %%
type(a)
# Out:
# long

# %%
print 20+23.45
# Out:
# 43.45

# %%
s="python"

# %%
type(s)
# Out:
# str

# %%
s1="str1"
s2="str2"
print s1+s2
# Out:
# str1str2

# %%
print s1*s2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-a9102ecc2f2a> in <module>()
# ----> 1 print s1*s2
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
print s1-s2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-1f9dc72bac7a> in <module>()
# ----> 1 print s1-s2
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
s1/s2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-b898b6e1307e> in <module>()
# ----> 1 s1/s2
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %%
a=raw_input("enter a value:")
# Out:
# enter a value:12

# %%
a
# Out:
# '12'

# %%
type(a)
# Out:
# str

# %%
a=20
s=a
s1="a"
print s
print s1
# Out:
# 20
# a

# %%
print a
# Out:
# 20

# %%
print "a"
# Out:
# a

# %%
name="apple"

# %%
productname="apple"

# %%
product_name = "apple"

# %%
product$name = "apple"
# Out:
#   File "<ipython-input-27-4f6ee25c8d88>", line 1
#     product$name = "apple"
#            ^
# SyntaxError: invalid syntax

# %%
name1="apple"

# %%
na1me="apple"

# %%
1name="apple"
# Out:
#   File "<ipython-input-30-f767c17c5561>", line 1
#     1name="apple"
#         ^
# SyntaxError: invalid syntax

# %%
a="product_cost: "
cost=23.45
print a+cost
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-81bada80403b> in <module>()
#       1 a="product_cost: "
#       2 cost=23.45
# ----> 3 print a+cost
#
# TypeError: cannot concatenate 'str' and 'float' objects

# %%
print a+str(cost)
# Out:
# product_cost: 23.45

# %%
a=raw_input("enter a value:")
b=raw_input("enter a value:")
print a+b
# Out:
# enter a value:12
# enter a value:34
# 1234

# %%
a=raw_input("enter a value:")
b=raw_input("enter a value:")
print int(a+b)
# Out:
# enter a value:12
# enter a value:34
# 1234

# %%
a=raw_input("enter a value:")
b=raw_input("enter a value:")
print int(a)+int(b)
# Out:
# enter a value:12
# enter a value:34
# 46

# %%
int?

# %%
int()
# Out:
# 0

# %%
int(23.45)
# Out:
# 23

# %%
int(23.45)
# Out:
# 23

# %%
int("23.45")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-0a57a8b372e3> in <module>()
# ----> 1 int("23.45")
#
# ValueError: invalid literal for int() with base 10: '23.45'

# %%
int("23")
# Out:
# 23

# %%
#base 10 0-9
int?

# %%
int("12a")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-c0e59e64096f> in <module>()
# ----> 1 int("12a")
#
# ValueError: invalid literal for int() with base 10: '12a'

# %%
int("42a",11)
# Out:
# 516

# %%
print 10*11**0+2*11**1+4*11**2
# Out:
# 516

# %%
a=123

# %%
a=0x12

# %%
a=12
b=012
print a,b
# Out:
# 12 10

# %%
a=0x12
b=0o12
c=0b0101
print a,b,c
# Out:
# 18 10 5

# %%
a=0xc
print a
# Out:
# 12

# %%
int("123",2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-ae99adeacf83> in <module>()
# ----> 1 int("123",2)
#
# ValueError: invalid literal for int() with base 2: '123'

# %%
c1=1+2j
c2=2+3j
print c1+c2
print c1-c2
print c1*c2
print c1/2
print c1**2
print c1%3
# Out:
# (3+5j)
# (-1-1j)
# (-4+7j)
# (0.5+1j)
# (-3+4j)
# (1+2j)
# C:\Users\samba\Anaconda2\lib\site-packages\ipykernel\__main__.py:8: DeprecationWarning: complex divmod(), // and % are deprecated

# %%
print c1+2
# Out:
# (3+2j)

# %%
a=2

# %%
complex(a)
# Out:
# (2+0j)

# %%
c1+"str1"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-7ba56ed1b1fe> in <module>()
# ----> 1 c1+"str1"
#
# TypeError: unsupported operand type(s) for +: 'complex' and 'str'

# %%
num = 1+2j
s1="number="
print num+s1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-c30670357d05> in <module>()
#       1 num = 1+2j
#       2 s1="number="
# ----> 3 print num+s1
#
# TypeError: unsupported operand type(s) for +: 'complex' and 'str'

# %%
num = 1+2j
s1="number="
print str(num)+s1
# Out:
# (1+2j)number=

# %%
s=12+23*3/45*5

# %%
a
# Out:
# 2

# %%
# operator precedency

# %%
a=23/34/10

# %%
a
# Out:
# 0

# %%
print 23*34/45*6
# Out:
# 102

# %%
a=python
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-ef502d63e904> in <module>()
# ----> 1 a=python
#
# NameError: name 'python' is not defined

# %%
a=true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-0834b8a3a65c> in <module>()
# ----> 1 a=true
#
# NameError: name 'true' is not defined

# %%
a=True

# %%
b=False

# %%
c=None

# %%
type(a)
# Out:
# bool

# %%
type(c)
# Out:
# NoneType

# %%
a=""

# %%
b=0

# %%
c=None

# %%
# bolean expressions

# %%
print a

# %%
print b
# Out:
# 0

# %%
print c
# Out:
# None

# %%
# > >= < <= is == != not in

# %%
10>20
# Out:
# False

# %%
bool(20>30)
# Out:
# False

# %%
20>=20
# Out:
# True

# %%
a=10
b=20

# %%
print bool(a>b)
# Out:
# False

# %%
print a>b
# Out:
# False

# %%
10==10
# Out:
# True

# %%
10==10.0
# Out:
# True

# %%
a=10
b=10.0
print a==b
print a is b
# Out:
# True
# True

# %%
a=10
b=a
print a is b
print a==b
# Out:
# True
# True

# %%
a=10
b=10.0
c=int(b)
print a==b
print a is c
# Out:
# True
# True

# %%
a=10
b=10.0
c=int(b)

# %%
a=10
b="2"
print a>b
# Out:
# False

# %%
print "1">2**200
# Out:
# True

# %%
print "12">"2"
# Out:
# False

# %%
print "12"<"2"
# Out:
# True

# %%
"apple","cat","banana"
# Out:
# ('apple', 'cat', 'banana')

# %%
"12","2","30","4"
# Out:
# ('12', '2', '30', '4')

# %%
print 1>2 and 2>3
# Out:
# False

# %%
print 1>2 or 2<4
# Out:
# True

# %%
print 1>2 and 2<4
# Out:
# False

# %%
print bool(0)
# Out:
# False

# %%
print bool(1)
# Out:
# True

# %%
print bool(-10)
# Out:
# True

# %%
print bool("python")
# Out:
# True

# %%
print bool("")
# Out:
# False

# %%
print bool(None)
# Out:
# False

# %%
print bool(True)
# Out:
# True

# %%
print bool(False)
# Out:
# False

# %%
print bool([])
# Out:
# False

# %%
print bool(())
# Out:
# False

# %%
print bool([1])
# Out:
# True

# %%
print bool((1))
# Out:
# True

# %%
print bool("")
# Out:
# False

# %%
print bool("0")
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
"pyt" in "python"
# Out:
# True

# %%
"java" in "python"
# Out:
# False

# %%
"PYT" in "python"
# Out:
# False

# %%
"py" not in "python"
# Out:
# False

# %%
"pt" in "pyhon"
# Out:
# False

# %%
"python"=="PYthon"
# Out:
# False

# %%
"python"!="Python"
# Out:
# True
