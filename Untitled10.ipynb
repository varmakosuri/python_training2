# %%
import requests

# %%
resp = requests.get('http://hubwaydatachallenge.org/api/v1/station/?format=json&username=sambapython&api_key=1a82d1609be7f3f49e6e493d0779cbb5ec634423')

# %%
resp.json()
# Out:
# {u'meta': {u'limit': 100,
#   u'next': None,
#   u'offset': 0,
#   u'previous': None,
#   u'total_count': 95},
#  u'objects': [{u'id': 3,
#    u'installdate': None,
#    u'installed': True,
#    u'locked': False,
#    u'name': u'Colleges of the Fenway',
#    u'point': {u'coordinates': [-71.100812, 42.340021], u'type': u'Point'},
#    u'removaldate': None,
#    u'resource_uri': u'/api/v1/station/3/',
#    u'temporary': False,
#    u'terminalname': u'B32006'},
#   {u'id': 4,
#    u'installdate': None,
#    u'installed': True,
#    u'locked': False,
#    u'name': u'Tremont St. at Berkeley St.',
#    u'point': {u'coordinates': [-71.069616, 42.345392], u'type': u'Point'},
#    u'removaldate': None,
#    u'resource_uri': u'/api/v1/station/4/',
#    u'temporary': False,
#    u'terminalname': u'C32000'},
#   {u'id': 5,
#    u'installdate': None,
#    u'installed': True,
#    u'locked': False,
#    u'name': u'Northeastern U / North Parking Lot',
# ...

# %%
resp  = requests.get('http://10.103.101.8:8889/remote/luns/lun',auth=('username','password'))
print resp.json()
'''
[{'id':1,'name':"n1"},{'id':2,'name':'name2'}]
'''

# %%
resp  = requests.get("http://127.0.0.1:9999/luns")

# %%
resp
# Out:
# <Response [200]>

# %%
resp.reason
# Out:
# 'OK'

# %%
resp.json()
# Out:
# [{u'id': 1, u'name': u'name1'}, {u'id': 2, u'name': u'name2'}]

# %%
resp  = requests.get("http://127.0.0.1:9999/iniatorgroups")

# %%
resp
# Out:
# <Response [200]>

# %%
resp.json()
# Out:
# [{u'id': 1, u'name': u'group1'}, {u'id': 2, u'name': u'group2'}]

# %%
resp  = requests.get?

# %%
resp  = requests.get("http://127.0.0.1:9999/iniatorgroups",params={'name':'lun1'},auth=('username','password'))

# %%
resp = requests.post("url",json={'lunname':"name1"."pool":"testpool","size":"12M"},auth=())

# %%
re
